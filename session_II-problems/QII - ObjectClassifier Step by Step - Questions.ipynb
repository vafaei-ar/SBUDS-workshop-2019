# %% [markdown]
# # There is a hint for each section, after the answer field
#
# ## first think then use the hint!
#
# ### Good luck

# %% [markdown]
# ### The-as-usual libraries (hamoon hamishegi!) + matplotlib inline magic

# %% [markdown]
# **HINT:**
#
# import numpy ...

# %% [markdown]
# ### Like previous section you have to read fits file and make a table from it
# ### so import fits and Table!

# %% [markdown]
# from a..... fits
# from astr....t Table

# %% [markdown]
# ### Open data file, read data from first entry and make a table from data

# %% [markdown]
# **HINT:**
#
# hdul = fits.open('....')  # open a FITS file
#
# data = h....l[1].data  # assume the first extension is a table
#
# tdata = Table.....ata)

# %% [markdown]
# ### Check if the data table you created

# %%
# Out:
# <Table length=500000>
#        objID         psfMag_u  psfMag_g ... extinction_z       z        class
#        int64         float32   float32  ...   float32       float32     str32
# ------------------- --------- --------- ... ------------ -------------- ------
# 1237659144022458452 19.779274 19.168108 ...  0.019556735      2.3617907    QSO
# 1237667910591905936   19.3976 19.209654 ...   0.03831502      1.4221603    QSO
# 1237650761323642960 20.927322 19.421354 ...  0.040449772     0.10520853 GALAXY
# 1237680481953252190 22.829788 22.509642 ...   0.05738621     0.42281336 GALAXY
# 1237661070871822366 20.725538 18.823456 ...   0.10666075     0.04353755 GALAXY
# 1237660025031885032 19.367426   17.4057 ...   0.07691282    0.053198155 GALAXY
# 1237667731272761908 23.048153 21.429382 ...   0.03832661     0.21652041 GALAXY
# 1237667733955215391  18.75221 18.611134 ...  0.047253583      1.6232141    QSO
# 1237669517435273366 19.726114 18.101149 ...   0.09364547 -0.00016427436   STAR
# ...

# %% [markdown]
# ### In the data we have column named `'class'` which specify the type of object
# ### Now create a list of three columns that:
#
# 1) if the object is STAR the row becomes:
#     [1, 0 , 0]
#
# 2) if the object is GALAXY the row becomes:
#     [0, 1, 0]
#
# 3) if the object is QSO the row becomes:
#     [0, 0, 1]

# %% [markdown]
# **HINT:**
#
# objects = np.array(tdata['class'])
#
# labels = []
#
# for i in range(len(objects)):
#
#     labels.append.....

# %%
labels
# Out:
# [[False, False, True],
#  [False, False, True],
#  [False, True, False],
#  [False, True, False],
#  [False, True, False],
#  [False, True, False],
#  [False, True, False],
#  [False, False, True],
#  [True, False, False],
#  [False, True, False],
#  [True, False, False],
#  [False, False, True],
#  [False, True, False],
#  [False, True, False],
#  [False, True, False],
#  [True, False, False],
#  [True, False, False],
#  [False, False, True],
#  [False, True, False],
#  [True, False, False],
#  [False, True, False],
#  [False, False, True],
#  [False, True, False],
#  [False, False, True],
#  [False, True, False],
#  [True, False, False],
#  [True, False, False],
#  [False, True, False],
#  [False, False, True],
#  [False, True, False],
#  [False, True, False],
#  [False, True, False],
#  [True, False, False],
#  [True, False, False],
#  [True, False, False],
#  [False, True, False],
#  [True, False, False],
#  [True, False, False],
#  [True, False, False],
#  [False, False, True],
# ...

# %% [markdown]
# ### This is logical list make it integer numpy array and find what index of array is maximum
# #### this is pretting neat way to

# %% [markdown]
# **HINT**
#
# labels = np.array......astype(int)
#
# labels

# %% [markdown]
# ### create parameter and and traget (type of galaxy), train and test sets

# %% [markdown]
# **HINT**
#
# n_train = 30000
#
# X_train = np.array(tdata['psfMag_u'

# %% [markdown]
# ## Import Needed library

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv1D, MaxPooling1D, Flatten
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Build the nueral network

# %% [markdown]
# **HINT**
#
# model = Sequen.......
#
# model.add(Dense(32......
#
# model.add(Dense(32,....
#
# model.add(Dense(32, ....
#
# model.add(Dense(16, ....
#
# model.add(Dropout(0....
#
# model.add(Dense(3, activ....

# %% [markdown]
# ## Compile the model

# %% [markdown]
# **HINT**
#
# model.compile(loss='categorica.....

# %% [markdown]
# ### Fit the model using training data

# %%
# HINT:

#model.fit(X_train,y_train,epochs=20,batch_size=100,verbose=1)
# Out:
# WARNING:tensorflow:From /home/majid/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 30000/30000 [==============================] - 3s 97us/step - loss: 1.5404 - acc: 0.4838
# Epoch 2/20
# 30000/30000 [==============================] - 2s 53us/step - loss: 0.7511 - acc: 0.6341
# Epoch 3/20
# 30000/30000 [==============================] - 1s 47us/step - loss: 0.5071 - acc: 0.8214
# Epoch 4/20
# 30000/30000 [==============================] - 1s 49us/step - loss: nan - acc: 0.4541
# Epoch 5/20
# 30000/30000 [==============================] - 1s 47us/step - loss: nan - acc: 0.3213
# Epoch 6/20
# 30000/30000 [==============================] - 2s 54us/step - loss: nan - acc: 0.3213
# Epoch 7/20
# 30000/30000 [==============================] - 2s 50us/step - loss: nan - acc: 0.3213
# Epoch 8/20
# ...

# %% [markdown]
# ### now evaluate the model

# %%
# model.evaluate(X_te....

# %%
y_pred = model.pred....
y_true = y_test....
y_pred = y_pred.argmax(axis..

# %%
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
#     classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
#     else:
#         print('Confusion matrix, without normalization')

#     print(cm)
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

plot_confusion_matrix(y_true, y_pred, ['STAR','GALAXY','QSO'],
                          normalize=1,title='CM')

# %%
# The out put is something like this but it must be different!
